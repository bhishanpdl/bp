# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imports" data-toc-modified-id="Imports-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imports</a></span></li><li><span><a href="#Load-data" data-toc-modified-id="Load-data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load data</a></span></li><li><span><a href="#Dark-Styles" data-toc-modified-id="Dark-Styles-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Dark Styles</a></span></li></ul></div>

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import bhishan
from bhishan import bp
import matplotlib.pyplot as plt

# %load_ext autoreload
# %load_ext watermark

# %autoreload 2
# %watermark -a "Bhishan Poudel" -d -v -m
# %watermark -iv
# Out:
# Bhishan Poudel 2020-09-28
#
# CPython 3.7.7
# IPython 7.18.1
#
# compiler   : Clang 4.0.1 (tags/RELEASE_401/final)
# system     : Darwin
# release    : 19.6.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 4
# interpreter: 64bit
# autopep8 1.5.2
# bhishan  0.3.1
# json     2.0.9
# pandas   1.1.0
# numpy    1.18.4
# seaborn  0.11.0

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %% [markdown]
# # Load data

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Dark Styles

# %%
mss = [-1,-2,-3,-100,-200,-300]

for ms in mss:
    df.bp.plot_cat('pclass',ms=ms,title=f"style: {ms}")

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
for ms in plt.style.available:
    df.bp.plot_cat('pclass',ms=ms,title=f"style: {ms}")
