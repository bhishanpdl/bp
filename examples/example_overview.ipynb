# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imports" data-toc-modified-id="Imports-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imports</a></span></li><li><span><a href="#Methods-available-in-module:-bp" data-toc-modified-id="Methods-available-in-module:-bp-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Methods available in module: bp</a></span></li><li><span><a href="#Data-Analysis-using-module:-bp" data-toc-modified-id="Data-Analysis-using-module:-bp-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Data Analysis using module: bp</a></span></li></ul></div>

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %load_ext autoreload
# %load_ext watermark

# %autoreload 2
# %watermark -a "Bhishan Poudel" -d -v -m
# %watermark -iv
# Out:
# Bhishan Poudel 2021-07-11
#
# CPython 3.7.7
# IPython 7.22.0
#
# compiler   : Clang 4.0.1 (tags/RELEASE_401/final)
# system     : Darwin
# release    : 19.6.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 4
# interpreter: 64bit
# seaborn 0.11.0
# numpy   1.19.5
# pandas  1.2.4

# %%
# my local library
import sys
sys.path.append("/Users/poudel/Dropbox/a00_Bhishan_Modules/")
sys.path.append("/Users/poudel/Dropbox/a00_Bhishan_Modules/bhishan")
from bhishan import bp

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
df = sns.load_dataset('titanic')
df.head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %% [markdown]
# # Methods available in module: bp

# %%
bp.show_methods(bp,5)
# Out:
#                                             0                              1  \
# 0                                  BPAccessor                   get_outliers
# 1                               Plotly_Charts               get_outliers_kde
# 2                                 RandomColor          get_plotly_colorscale
# 3                            add_interactions  get_yprobs_sorted_proportions
# 4                            add_text_barplot                     hex_to_rgb
# 5                                  adjustedR2                            hlp
# 6                                    colorsys                           json
# 7                               discrete_cmap                     light_axis
# 8                            display_calendar                        lm_plot
# 9                             donut_plot_binn          lm_residual_corr_plot
# 10                                  find_corr                       lm_stats
# ...

# %%
bp.show_methods(bp,contains='plotly')
# Out:
#                                         0                    1  \
# 0                   get_plotly_colorscale    plotly_bubbleplot
# 1            plot_confusion_matrix_plotly  plotly_corr_heatmap
# 2                 plotly_agg_country_plot     plotly_countplot
# 3                     plotly_agg_usa_plot  plotly_country_plot
# 4            plotly_binary_clf_evaluation      plotly_distplot
# 5                          plotly_boxplot     plotly_histogram
# 6  plotly_boxplot_allpoints_with_outliers        plotly_mapbox
# 7       plotly_boxplot_categorical_column
#
#                                 2
# 0               plotly_radar_plot
# 1           plotly_scattergl_plot
# 2  plotly_scattergl_plot_colorcol
# 3  plotly_scattergl_plot_subplots
# 4           plotly_usa_bubble_map
# 5                  plotly_usa_map
# 6                 plotly_usa_map2
# 7

# %%
# plotting functions
bp.show_methods(bp,contains='plot_',ncols=5)
# Out:
#                        0                             1  \
# 0        donut_plot_binn                  plot_cat_num
# 1  plot_boxplot_cats_num  plot_confusion_matrix_plotly
# 2               plot_cat                     plot_corr
# 3          plot_cat_binn               plot_corr_style
# 4           plot_cat_cat   plot_corrplot_with_pearsonr
# 5          plot_cat_cat2                plot_count_cat
# 6       plot_cat_cat_pct                plot_daily_cat
#
#                                         2                              3  \
# 0                           plot_date_cat                  plot_num_cat2
# 1                               plot_ecdf                   plot_num_num
# 2                               plot_gini                    plot_pareto
# 3                                 plot_ks                   plot_roc_auc
# 4  plot_multiple_jointplots_with_pearsonr                   plot_roc_skf
# 5                                plot_num  plot_simple_linear_regression
# ...

# %%
# methods for correlation
bp.show_methods(bp,contains='corr')
# Out:
#                                  0                1  \
# 0                        find_corr     partial_corr
# 1  get_high_correlated_features_df        plot_corr
# 2            lm_residual_corr_plot  plot_corr_style
#
#                              2
# 0  plot_corrplot_with_pearsonr
# 1          plotly_corr_heatmap
# 2   point_biserial_correlation

# %%
# methods for outliers
bp.show_methods(bp,contains='outliers',ncols=5)
# Out:
#               0                 1                                       2  \
# 0  get_outliers  get_outliers_kde  plotly_boxplot_allpoints_with_outliers
#
#                  3 4
# 0  remove_outliers

# %%
# methods for color
bp.show_methods(bp,contains='color')
# Out:
#                      0                      1                               2
# 0             colorsys  get_plotly_colorscale  plotly_scattergl_plot_colorcol
# 1  get_distinct_colors

# %%
# methods for map 
bp.show_methods(bp,contains='map')
# Out:
#                      0                      1                2
# 0        discrete_cmap          plotly_mapbox   plotly_usa_map
# 1  plotly_corr_heatmap  plotly_usa_bubble_map  plotly_usa_map2

# %%
# methods for pandas dataframe
bp.show_methods(bp.BPAccessor,ncols=5)
# Out:
#                        0                      1                 2  \
# 0              SORT_FLAG                missing  plot_cat_stacked
# 1           compare_kde2           outliers_kde         plot_corr
# 2       compare_kde_binn         outliers_tukey     plot_corr_sns
# 3              corr_high           partial_corr   plot_corr_style
# 4          corr_high_lst  plot_boxplot_cats_num    plot_count_cat
# 5              countplot               plot_cat    plot_daily_cat
# 6               describe           plot_cat_cat     plot_date_cat
# 7                   freq          plot_cat_cat2         plot_ecdf
# 8  get_duplicate_columns           plot_cat_num
#
#                   3                4
# 0          plot_num  plotly_yearplot
# 1      plot_num_cat     regplot_binn
# 2      plot_num_num      style_cellv
# 3       plot_pareto      style_cellx
# 4   plot_statistics       style_diag
# 5    plotly_boxplot     style_rowcol
# 6       plotly_corr         subtotal
# ...

# %%
# methods for statistics
bp.show_methods(bp,contains='stat')
# Out:
#           0                1                          2
# 0  lm_stats  plot_statistics  print_statsmodels_summary

# %%
# methods for calendar
bp.show_methods(bp,contains='calen')
# Out:
#                   0               1 2
# 0  display_calendar  print_calendar

# %% [markdown]
# # Data Analysis using module: bp

# %%
# detailed description using my module bp
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))


df.bp.describe()
# Out:
# <style>.container { width:100% !important; }</style>
# <style  type="text/css" >
# #T_e7bb4_row0_col1,#T_e7bb4_row2_col1,#T_e7bb4_row3_col1,#T_e7bb4_row11_col1,#T_e7bb4_row12_col1,#T_e7bb4_row13_col1,#T_e7bb4_row14_col1{
#             background:  salmon;
#         }#T_e7bb4_row0_col6,#T_e7bb4_row4_col8,#T_e7bb4_row7_col10,#T_e7bb4_row8_col10{
#             background-color:  #023858;
#             color:  #f1f1f1;
# ...
