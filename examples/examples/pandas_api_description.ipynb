# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Description" data-toc-modified-id="Description-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Description</a></span></li><li><span><a href="#Imports" data-toc-modified-id="Imports-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Imports</a></span></li><li><span><a href="#Using-plotly-api-in-module-bhishan" data-toc-modified-id="Using-plotly-api-in-module-bhishan-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Using plotly api in module bhishan</a></span></li></ul></div>

# %% [markdown]
# # Description
# This is an example tutorial to use my module bhishan for the plotly
# extension for pandas.

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import bhishan
from bhishan import bp
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Using plotly api in module bhishan

# %%
# print(sns.get_dataset_names())

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.bp.freq(['embarked'],style=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_5bac10ba_c0a3_11ea_93c3_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >embarked</th>        <th class="col_heading level0 col1" >Count</th>        <th class="col_heading level0 col2" >Percent</th>        <th class="col_heading level0 col3" >Cumulative Count</th>        <th class="col_heading level0 col4" >Cumulative Percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5bac10ba_c0a3_11ea_93c3_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5bac10ba_c0a3_11ea_93c3_acde48001122row0_col0" class="data row0 col0" >S</td>
#                         <td id="T_5bac10ba_c0a3_11ea_93c3_acde48001122row0_col1" class="data row0 col1" >644</td>
#                         <td id="T_5bac10ba_c0a3_11ea_93c3_acde48001122row0_col2" class="data row0 col2" >72.44%</td>
#                         <td id="T_5bac10ba_c0a3_11ea_93c3_acde48001122row0_col3" class="data row0 col3" >644</td>
#                         <td id="T_5bac10ba_c0a3_11ea_93c3_acde48001122row0_col4" class="data row0 col4" >72.44%</td>
#             </tr>
#             <tr>
#                         <th id="T_5bac10ba_c0a3_11ea_93c3_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5bac10ba_c0a3_11ea_93c3_acde48001122row1_col0" class="data row1 col0" >C</td>
#                         <td id="T_5bac10ba_c0a3_11ea_93c3_acde48001122row1_col1" class="data row1 col1" >168</td>
#                         <td id="T_5bac10ba_c0a3_11ea_93c3_acde48001122row1_col2" class="data row1 col2" >18.90%</td>
#                         <td id="T_5bac10ba_c0a3_11ea_93c3_acde48001122row1_col3" class="data row1 col3" >812</td>
#                         <td id="T_5bac10ba_c0a3_11ea_93c3_acde48001122row1_col4" class="data row1 col4" >91.34%</td>
#             </tr>
#             <tr>
#                         <th id="T_5bac10ba_c0a3_11ea_93c3_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_5bac10ba_c0a3_11ea_93c3_acde48001122row2_col0" class="data row2 col0" >Q</td>
#                         <td id="T_5bac10ba_c0a3_11ea_93c3_acde48001122row2_col1" class="data row2 col1" >77</td>
#                         <td id="T_5bac10ba_c0a3_11ea_93c3_acde48001122row2_col2" class="data row2 col2" >8.66%</td>
#                         <td id="T_5bac10ba_c0a3_11ea_93c3_acde48001122row2_col3" class="data row2 col3" >889</td>
#                         <td id="T_5bac10ba_c0a3_11ea_93c3_acde48001122row2_col4" class="data row2 col4" >100.00%</td>
#             </tr>
#     </tbody></table>

# %%
df.bp.describe()
# Out:
# <style  type="text/css" >
#     #T_5bbfe824_c0a3_11ea_93c3_acde48001122row0_col1 {
#             background:  salmon;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row0_col6 {
#             : ;
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row0_col8 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row1_col6 {
#             : ;
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row1_col8 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row2_col1 {
#             background:  salmon;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row2_col6 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row2_col8 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row3_col1 {
#             background:  salmon;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row3_col6 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row3_col8 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row4_col6 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row4_col8 {
#             : ;
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row5_col6 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row5_col8 {
#             : ;
#             background-color:  #045483;
#             color:  #f1f1f1;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row6_col6 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row6_col8 {
#             : ;
#             background-color:  #05659f;
#             color:  #f1f1f1;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row7_col6 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row7_col8 {
#             : ;
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row8_col6 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row8_col8 {
#             : ;
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row9_col6 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row9_col8 {
#             : ;
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row10_col6 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row10_col8 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row11_col1 {
#             background:  salmon;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row11_col6 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row11_col8 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row12_col1 {
#             background:  salmon;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row12_col6 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row12_col8 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row13_col1 {
#             background:  salmon;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row13_col6 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row13_col8 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row14_col1 {
#             background:  salmon;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row14_col6 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5bbfe824_c0a3_11ea_93c3_acde48001122row14_col8 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_5bbfe824_c0a3_11ea_93c3_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Type</th>        <th class="col_heading level0 col2" >N</th>        <th class="col_heading level0 col3" >Count</th>        <th class="col_heading level0 col4" >Unique</th>        <th class="col_heading level0 col5" >Missing</th>        <th class="col_heading level0 col6" >MissingPct</th>        <th class="col_heading level0 col7" >Zeros</th>        <th class="col_heading level0 col8" >ZerosPct</th>        <th class="col_heading level0 col9" >mean</th>        <th class="col_heading level0 col10" >std</th>        <th class="col_heading level0 col11" >min</th>        <th class="col_heading level0 col12" >max</th>        <th class="col_heading level0 col13" >25%</th>        <th class="col_heading level0 col14" >50%</th>        <th class="col_heading level0 col15" >75%</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5bbfe824_c0a3_11ea_93c3_acde48001122level0_row0" class="row_heading level0 row0" >11</th>
#                         <td id="T_5bbfe824_c0a3_11ea_93c3_acde48001122row0_col0" class="data row0 col0" >deck</td>
#                         <td id="T_5bbfe824_c0a3_11ea_93c3_acde48001122row0_col1" class="data row0 col1" >category</td>
#                         <td id="T_5bbfe824_c0a3_11ea_93c3_acde48001122row0_col2" class="data row0 col2" >891</td>
#                         <td id="T_5bbfe824_c0a3_11ea_93c3_acde48001122row0_col3" class="data row0 col3" >203</td>
#                         <td id="T_5bbfe824_c0a3_11ea_93c3_acde48001122row0_col4" class="data row0 col4" >7</td>
#                         <td id="T_5bbfe824_c0a3_11ea_93c3_acde48001122row0_col5" class="data row0 col5" >688</td>
#                         <td id="T_5bbfe824_c0a3_11ea_93c3_acde48001122row0_col6" class="data row0 col6" >77.22</td>
#                         <td id="T_5bbfe824_c0a3_11ea_93c3_acde48001122row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_5bbfe824_c0a3_11ea_93c3_acde48001122row0_col8" class="data row0 col8" >0.00</td>
#                         <td id="T_5bbfe824_c0a3_11ea_93c3_acde48001122row0_col9" class="data row0 col9" ></td>
#                         <td id="T_5bbfe824_c0a3_11ea_93c3_acde48001122row0_col10" class="data row0 col10" ></td>
#                         <td id="T_5bbfe824_c0a3_11ea_93c3_acde48001122row0_col11" class="data row0 col11" ></td>
#                         <td id="T_5bbfe824_c0a3_11ea_93c3_acde48001122row0_col12" class="data row0 col12" ></td>
#                         <td id="T_5bbfe824_c0a3_11ea_93c3_acde48001122row0_col13" class="data row0 col13" ></td>
#                         <td id="T_5bbfe824_c0a3_11ea

# %%
df.bp.get_duplicate_columns()
# Out:
# []

# %%
df.dtypes
# Out:
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# dtype: object

# %%
df1 = pd.DataFrame({'a': range(3),'b':range(1,4),'a_dup':range(3)})
df1
# Out:
#    a  b  a_dup
# 0  0  1      0
# 1  1  2      1
# 2  2  3      2

# %%
df1.bp.get_duplicate_columns()
# Out:
# a == a_dup
# ['a_dup']

# %%
df.bp.missing()
# Out:
# Missing values high threshold = 80%
#
# Number of missing values features: 4
# cols_missing_high = []
# cols_missing_low = ['deck', 'age', 'embarked', 'embark_town']
# <style  type="text/css" >
#     #T_5c2d5210_c0a3_11ea_93c3_acde48001122row0_col1 {
#             background:  salmon;
#         }    #T_5c2d5210_c0a3_11ea_93c3_acde48001122row0_col6 {
#             : ;
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5c2d5210_c0a3_11ea_93c3_acde48001122row0_col7 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5c2d5210_c0a3_11ea_93c3_acde48001122row1_col6 {
#             : ;
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_5c2d5210_c0a3_11ea_93c3_acde48001122row1_col7 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5c2d5210_c0a3_11ea_93c3_acde48001122row2_col1 {
#             background:  salmon;
#         }    #T_5c2d5210_c0a3_11ea_93c3_acde48001122row2_col6 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5c2d5210_c0a3_11ea_93c3_acde48001122row2_col7 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5c2d5210_c0a3_11ea_93c3_acde48001122row3_col1 {
#             background:  salmon;
#         }    #T_5c2d5210_c0a3_11ea_93c3_acde48001122row3_col6 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5c2d5210_c0a3_11ea_93c3_acde48001122row3_col7 {
#             : ;
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_5c2d5210_c0a3_11ea_93c3_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Type</th>        <th class="col_heading level0 col2" >Count</th>        <th class="col_heading level0 col3" >Missing</th>        <th class="col_heading level0 col4" >Zeros</th>        <th class="col_heading level0 col5" >Unique</th>        <th class="col_heading level0 col6" >MissingPct</th>        <th class="col_heading level0 col7" >ZerosPct</th>        <th class="col_heading level0 col8" >count</th>        <th class="col_heading level0 col9" >mean</th>        <th class="col_heading level0 col10" >std</th>        <th class="col_heading level0 col11" >min</th>        <th class="col_heading level0 col12" >25%</th>        <th class="col_heading level0 col13" >50%</th>        <th class="col_heading level0 col14" >75%</th>        <th class="col_heading level0 col15" >max</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5c2d5210_c0a3_11ea_93c3_acde48001122level0_row0" class="row_heading level0 row0" >11</th>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row0_col0" class="data row0 col0" >deck</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row0_col1" class="data row0 col1" >object</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row0_col2" class="data row0 col2" >891</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row0_col3" class="data row0 col3" >688</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row0_col5" class="data row0 col5" >7</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row0_col6" class="data row0 col6" >77.216611</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row0_col7" class="data row0 col7" >0.000000</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row0_col8" class="data row0 col8" ></td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row0_col9" class="data row0 col9" ></td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row0_col10" class="data row0 col10" ></td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row0_col11" class="data row0 col11" ></td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row0_col12" class="data row0 col12" ></td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row0_col13" class="data row0 col13" ></td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row0_col14" class="data row0 col14" ></td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row0_col15" class="data row0 col15" ></td>
#             </tr>
#             <tr>
#                         <th id="T_5c2d5210_c0a3_11ea_93c3_acde48001122level0_row1" class="row_heading level0 row1" >3</th>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row1_col0" class="data row1 col0" >age</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row1_col1" class="data row1 col1" >float64</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row1_col2" class="data row1 col2" >891</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row1_col3" class="data row1 col3" >177</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row1_col4" class="data row1 col4" >0</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row1_col5" class="data row1 col5" >88</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row1_col6" class="data row1 col6" >19.865320</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row1_col7" class="data row1 col7" >0.000000</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row1_col8" class="data row1 col8" >714.000000</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row1_col9" class="data row1 col9" >29.699118</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row1_col10" class="data row1 col10" >14.526497</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row1_col11" class="data row1 col11" >0.420000</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row1_col12" class="data row1 col12" >20.125000</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row1_col13" class="data row1 col13" >28.000000</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row1_col14" class="data row1 col14" >38.000000</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row1_col15" class="data row1 col15" >80.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_5c2d5210_c0a3_11ea_93c3_acde48001122level0_row2" class="row_heading level0 row2" >7</th>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row2_col0" class="data row2 col0" >embarked</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row2_col1" class="data row2 col1" >object</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row2_col2" class="data row2 col2" >891</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row2_col3" class="data row2 col3" >2</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row2_col4" class="data row2 col4" >0</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row2_col5" class="data row2 col5" >3</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row2_col6" class="data row2 col6" >0.224467</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row2_col7" class="data row2 col7" >0.000000</td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row2_col8" class="data row2 col8" ></td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row2_col9" class="data row2 col9" ></td>
#                         <td id="T_5c2d5210_c0a3_11ea_93c3_acde48001122row2_col10" class="data row2 col10" ></td>
#                         <td
