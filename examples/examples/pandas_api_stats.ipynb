# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Description" data-toc-modified-id="Description-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Description</a></span></li><li><span><a href="#Imports" data-toc-modified-id="Imports-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Imports</a></span></li><li><span><a href="#Using-plotly-api-in-module-bhishan" data-toc-modified-id="Using-plotly-api-in-module-bhishan-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Using plotly api in module bhishan</a></span></li><li><span><a href="#Correlation" data-toc-modified-id="Correlation-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Correlation</a></span></li><li><span><a href="#Partial-Correlation" data-toc-modified-id="Partial-Correlation-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Partial Correlation</a></span></li><li><span><a href="#Outliers" data-toc-modified-id="Outliers-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Outliers</a></span></li><li><span><a href="#Kernel-Density" data-toc-modified-id="Kernel-Density-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Kernel Density</a></span></li></ul></div>

# %% [markdown]
# # Description
# This is an example tutorial to use my module bhishan for the plotly
# extension for pandas.

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import bhishan
from bhishan import bp
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Using plotly api in module bhishan

# %%
# print(sns.get_dataset_names())

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Correlation

# %%
df.bp.plot_corr(xrot=0)

# %%
df.bp.plot_corr(target='survived')

# %%
target = 'survived'
df_few_cols = df[['age','fare']]
df_few_cols.merge(df[target],left_index=True,right_index=True)\
           .bp.plot_corr()
# Out:
# /Users/poudel/Dropbox/a00_Bhishan_Modules/bhishan/pandas_api.py:38: UserWarning:
#
# registration of accessor <class 'bhishan.pandas_api.BPAccessor'> under name 'bp' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexistingattribute with the same name.

# %%
df.bp.plot_corr_style()
# Out:
# <style  type="text/css" >
#     #T_f737528a_c0a1_11ea_bb0e_acde48001122 th {
#           font-size: 7pt;
#     }    #T_f737528a_c0a1_11ea_bb0e_acde48001122 td {
#           padding: 0em 0em;
#     }    #T_f737528a_c0a1_11ea_bb0e_acde48001122 th:hover {
#           font-size: 12pt;
#     }    #T_f737528a_c0a1_11ea_bb0e_acde48001122 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row0_col0 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row0_col1 {
#             background-color:  #bf3338;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row0_col2 {
#             background-color:  #f5a886;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row0_col3 {
#             background-color:  #f7b799;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row0_col4 {
#             background-color:  #fcdecd;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row0_col5 {
#             background-color:  #eff3f5;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row0_col6 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row0_col7 {
#             background-color:  #de735c;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row1_col0 {
#             background-color:  #be3036;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row1_col1 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row1_col2 {
#             background-color:  #b72230;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row1_col3 {
#             background-color:  #fdddcb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row1_col4 {
#             background-color:  #fac8af;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row1_col5 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row1_col6 {
#             background-color:  #fcdfcf;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row1_col7 {
#             background-color:  #fae7dc;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row2_col0 {
#             background-color:  #da6853;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row2_col1 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row2_col2 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row2_col3 {
#             background-color:  #870a24;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row2_col4 {
#             background-color:  #bd2d35;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row2_col5 {
#             background-color:  #f7b99c;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row2_col6 {
#             background-color:  #f9f0eb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row2_col7 {
#             background-color:  #fcdfcf;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row3_col0 {
#             background-color:  #f8bda1;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row3_col1 {
#             background-color:  #fce0d0;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row3_col2 {
#             background-color:  #cc4c44;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row3_col3 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row3_col4 {
#             background-color:  #bddbea;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row3_col5 {
#             background-color:  #f9efe9;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row3_col6 {
#             background-color:  #d86551;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row3_col7 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row4_col0 {
#             background-color:  #fce0d0;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row4_col1 {
#             background-color:  #fbd0b9;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row4_col2 {
#             background-color:  #e48066;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row4_col3 {
#             background-color:  #bddbea;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row4_col4 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row4_col5 {
#             background-color:  #f5f6f7;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row4_col6 {
#             background-color:  #c2383a;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_f737528a_c0a1_11ea_bb0e_acde48001122row4_col7 {
#             backgro

# %%
# df.bp.plot_corr_sns()

# %%
df.corr().style.apply(lambda x: ["background: salmon" if  (abs(v) > 0.5 and v!=1) else "" for v in x], axis = 1)
# Out:
# <style  type="text/css" >
#     #T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row0_col6 {
#             background:  salmon;
#         }    #T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row1_col5 {
#             background:  salmon;
#         }    #T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row3_col7 {
#             background:  salmon;
#         }    #T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row4_col7 {
#             background:  salmon;
#         }    #T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row5_col1 {
#             background:  salmon;
#         }    #T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row6_col0 {
#             background:  salmon;
#         }    #T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row7_col3 {
#             background:  salmon;
#         }    #T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row7_col4 {
#             background:  salmon;
#         }</style><table id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >survived</th>        <th class="col_heading level0 col1" >pclass</th>        <th class="col_heading level0 col2" >age</th>        <th class="col_heading level0 col3" >sibsp</th>        <th class="col_heading level0 col4" >parch</th>        <th class="col_heading level0 col5" >fare</th>        <th class="col_heading level0 col6" >adult_male</th>        <th class="col_heading level0 col7" >alone</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122level0_row0" class="row_heading level0 row0" >survived</th>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row0_col1" class="data row0 col1" >-0.338481</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row0_col2" class="data row0 col2" >-0.077221</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row0_col3" class="data row0 col3" >-0.035322</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row0_col4" class="data row0 col4" >0.081629</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row0_col5" class="data row0 col5" >0.257307</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row0_col6" class="data row0 col6" >-0.557080</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row0_col7" class="data row0 col7" >-0.203367</td>
#             </tr>
#             <tr>
#                         <th id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122level0_row1" class="row_heading level0 row1" >pclass</th>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row1_col0" class="data row1 col0" >-0.338481</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row1_col2" class="data row1 col2" >-0.369226</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row1_col3" class="data row1 col3" >0.083081</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row1_col4" class="data row1 col4" >0.018443</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row1_col5" class="data row1 col5" >-0.549500</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row1_col6" class="data row1 col6" >0.094035</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row1_col7" class="data row1 col7" >0.135207</td>
#             </tr>
#             <tr>
#                         <th id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122level0_row2" class="row_heading level0 row2" >age</th>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row2_col0" class="data row2 col0" >-0.077221</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row2_col1" class="data row2 col1" >-0.369226</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row2_col3" class="data row2 col3" >-0.308247</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row2_col4" class="data row2 col4" >-0.189119</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row2_col5" class="data row2 col5" >0.096067</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row2_col6" class="data row2 col6" >0.280328</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row2_col7" class="data row2 col7" >0.198270</td>
#             </tr>
#             <tr>
#                         <th id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122level0_row3" class="row_heading level0 row3" >sibsp</th>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row3_col0" class="data row3 col0" >-0.035322</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row3_col1" class="data row3 col1" >0.083081</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row3_col2" class="data row3 col2" >-0.308247</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row3_col4" class="data row3 col4" >0.414838</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row3_col5" class="data row3 col5" >0.159651</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row3_col6" class="data row3 col6" >-0.253586</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row3_col7" class="data row3 col7" >-0.584471</td>
#             </tr>
#             <tr>
#                         <th id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122level0_row4" class="row_heading level0 row4" >parch</th>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row4_col0" class="data row4 col0" >0.081629</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row4_col1" class="data row4 col1" >0.018443</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row4_col2" class="data row4 col2" >-0.189119</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row4_col3" class="data row4 col3" >0.414838</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row4_col5" class="data row4 col5" >0.216225</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row4_col6" class="data row4 col6" >-0.349943</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row4_col7" class="data row4 col7" >-0.583398</td>
#             </tr>
#             <tr>
#                         <th id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122level0_row5" class="row_heading level0 row5" >fare</th>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row5_col0" class="data row5 col0" >0.257307</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row5_col1" class="data row5 col1" >-0.549500</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row5_col2" class="data row5 col2" >0.096067</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row5_col3" class="data row5 col3" >0.159651</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row5_col4" class="data row5 col4" >0.216225</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row5_col5" class="data row5 col5" >1.000000</td>
#                         <td id="T_f74e0d5e_c0a1_11ea_bb0e_acde48001122row5_col6" class="data row5 col6" >-0.182024</td>
#                         <td id="T_f74e0d

# %%
df.bp.corr_high(thr=0.5,disp=True)
# Out:
# cols_high_corr = ['parch', 'survived', 'sibsp', 'adult_male', 'fare', 'pclass', 'alone']
# cols_high_corr1 = ['fare', 'survived', 'parch', 'alone']
# cols_high_corr2 = ['pclass', 'adult_male', 'alone', 'sibsp']
# cols_high_corr_drop = ['fare', 'parch', 'survived']
# <style  type="text/css" >
#     #T_f75c6890_c0a1_11ea_bb0e_acde48001122row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f75c6890_c0a1_11ea_bb0e_acde48001122row1_col2 {
#             background-color:  #056aa6;
#             color:  #f1f1f1;
#         }    #T_f75c6890_c0a1_11ea_bb0e_acde48001122row2_col2 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_f75c6890_c0a1_11ea_bb0e_acde48001122row3_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_f75c6890_c0a1_11ea_bb0e_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >feature1</th>        <th class="col_heading level0 col1" >feature2</th>        <th class="col_heading level0 col2" >corr</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f75c6890_c0a1_11ea_bb0e_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f75c6890_c0a1_11ea_bb0e_acde48001122row0_col0" class="data row0 col0" >fare</td>
#                         <td id="T_f75c6890_c0a1_11ea_bb0e_acde48001122row0_col1" class="data row0 col1" >pclass</td>
#                         <td id="T_f75c6890_c0a1_11ea_bb0e_acde48001122row0_col2" class="data row0 col2" >-0.549500</td>
#             </tr>
#             <tr>
#                         <th id="T_f75c6890_c0a1_11ea_bb0e_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f75c6890_c0a1_11ea_bb0e_acde48001122row1_col0" class="data row1 col0" >survived</td>
#                         <td id="T_f75c6890_c0a1_11ea_bb0e_acde48001122row1_col1" class="data row1 col1" >adult_male</td>
#                         <td id="T_f75c6890_c0a1_11ea_bb0e_acde48001122row1_col2" class="data row1 col2" >-0.557080</td>
#             </tr>
#             <tr>
#                         <th id="T_f75c6890_c0a1_11ea_bb0e_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f75c6890_c0a1_11ea_bb0e_acde48001122row2_col0" class="data row2 col0" >parch</td>
#                         <td id="T_f75c6890_c0a1_11ea_bb0e_acde48001122row2_col1" class="data row2 col1" >alone</td>
#                         <td id="T_f75c6890_c0a1_11ea_bb0e_acde48001122row2_col2" class="data row2 col2" >-0.583398</td>
#             </tr>
#             <tr>
#                         <th id="T_f75c6890_c0a1_11ea_bb0e_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f75c6890_c0a1_11ea_bb0e_acde48001122row3_col0" class="data row3 col0" >alone</td>
#                         <td id="T_f75c6890_c0a1_11ea_bb0e_acde48001122row3_col1" class="data row3 col1" >sibsp</td>
#                         <td id="T_f75c6890_c0a1_11ea_bb0e_acde48001122row3_col2" class="data row3 col2" >-0.584471</td>
#             </tr>
#     </tbody></table>

# %%
cols_high_corr_drop = ['fare', 'parch', 'survived']

# %%
df1 = df.drop(cols_high_corr_drop,axis=1)
df1.corr()
# Out:
#               pclass       age     sibsp  adult_male     alone
# pclass      1.000000 -0.369226  0.083081    0.094035  0.135207
# age        -0.369226  1.000000 -0.308247    0.280328  0.198270
# sibsp       0.083081 -0.308247  1.000000   -0.253586 -0.584471
# adult_male  0.094035  0.280328 -0.253586    1.000000  0.404744
# alone       0.135207  0.198270 -0.584471    0.404744  1.000000

# %% [markdown]
# # Partial Correlation

# %%
df.bp.partial_corr(thr=0.3,disp=True)
# Out:
# <style  type="text/css" >
#     #T_f783e33e_c0a1_11ea_bb0e_acde48001122row1_col2 {
#             background:  salmon;
#         }    #T_f783e33e_c0a1_11ea_bb0e_acde48001122row2_col1 {
#             background:  salmon;
#         }</style><table id="T_f783e33e_c0a1_11ea_bb0e_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >survived</th>        <th class="col_heading level0 col1" >pclass</th>        <th class="col_heading level0 col2" >age</th>        <th class="col_heading level0 col3" >sibsp</th>        <th class="col_heading level0 col4" >parch</th>        <th class="col_heading level0 col5" >fare</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f783e33e_c0a1_11ea_bb0e_acde48001122level0_row0" class="row_heading level0 row0" >survived</th>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row0_col1" class="data row0 col1" >0.115371</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row0_col2" class="data row0 col2" >0.111542</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row0_col3" class="data row0 col3" >-0.028674</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row0_col4" class="data row0 col4" >0.082447</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row0_col5" class="data row0 col5" >0.301210</td>
#             </tr>
#             <tr>
#                         <th id="T_f783e33e_c0a1_11ea_bb0e_acde48001122level0_row1" class="row_heading level0 row1" >pclass</th>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row1_col0" class="data row1 col0" >0.115371</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row1_col2" class="data row1 col2" >0.571910</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row1_col3" class="data row1 col3" >0.306844</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row1_col4" class="data row1 col4" >0.173285</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row1_col5" class="data row1 col5" >-0.315652</td>
#             </tr>
#             <tr>
#                         <th id="T_f783e33e_c0a1_11ea_bb0e_acde48001122level0_row2" class="row_heading level0 row2" >age</th>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row2_col0" class="data row2 col0" >0.111542</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row2_col1" class="data row2 col1" >0.571910</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row2_col3" class="data row2 col3" >-0.192800</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row2_col4" class="data row2 col4" >-0.095105</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row2_col5" class="data row2 col5" >0.392652</td>
#             </tr>
#             <tr>
#                         <th id="T_f783e33e_c0a1_11ea_bb0e_acde48001122level0_row3" class="row_heading level0 row3" >sibsp</th>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row3_col0" class="data row3 col0" >-0.028674</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row3_col1" class="data row3 col1" >0.306844</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row3_col2" class="data row3 col2" >-0.192800</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row3_col4" class="data row3 col4" >0.324787</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row3_col5" class="data row3 col5" >0.211403</td>
#             </tr>
#             <tr>
#                         <th id="T_f783e33e_c0a1_11ea_bb0e_acde48001122level0_row4" class="row_heading level0 row4" >parch</th>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row4_col0" class="data row4 col0" >0.082447</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row4_col1" class="data row4 col1" >0.173285</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row4_col2" class="data row4 col2" >-0.095105</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row4_col3" class="data row4 col3" >0.324787</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row4_col5" class="data row4 col5" >0.199136</td>
#             </tr>
#             <tr>
#                         <th id="T_f783e33e_c0a1_11ea_bb0e_acde48001122level0_row5" class="row_heading level0 row5" >fare</th>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row5_col0" class="data row5 col0" >0.301210</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row5_col1" class="data row5 col1" >-0.315652</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row5_col2" class="data row5 col2" >0.392652</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row5_col3" class="data row5 col3" >0.211403</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row5_col4" class="data row5 col4" >0.199136</td>
#                         <td id="T_f783e33e_c0a1_11ea_bb0e_acde48001122row5_col5" class="data row5 col5" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
df.bp.partial_corr(['fare','age'])
# Out:
#           fare       age
# fare  1.000000  0.096067
# age   0.096067  1.000000

# %% [markdown]
# # Outliers

# %%
ser_outliers = df.bp.outliers_tukey('age')
ser_outliers
# Out:
#       age
# 33   66.0
# 54   65.0
# 96   71.0
# 116  70.5
# 280  65.0
# 456  65.0
# 493  71.0
# 630  80.0
# 672  70.0
# 745  70.0
# 851  74.0

# %%
col = 'age'
df1 = df.dropna(subset=[col]).reset_index(drop=True)
idx_outliers, val_outliers = df1.bp.outliers_kde(col)
df1.loc[idx_outliers,[col]]
# Out:
#       age
# 498  80.0
# 679  74.0
# 74   71.0
# 393  71.0
# 91   70.5
# 531  70.0
# 592  70.0
# 25   66.0
# 366  65.0
# 225  65.0
# 40   65.0
# 351  64.0
# 433  64.0
# 385  63.0
# 221  63.0

# %% [markdown]
# # Kernel Density

# %%
df.bp.compare_kde_binn('age','survived')
# Out:
# /Users/poudel/Dropbox/a00_Bhishan_Modules/bhishan/pandas_api.py:38: UserWarning:
#
# registration of accessor <class 'bhishan.pandas_api.BPAccessor'> under name 'bp' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexistingattribute with the same name.
